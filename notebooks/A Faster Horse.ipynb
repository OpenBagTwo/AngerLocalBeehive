# %% [markdown]
# # A Faster Horse
#
# Just a quick script to check the stats of all my equines.

# %%
import json
from concurrent.futures import ProcessPoolExecutor, as_completed
from os import environ
from pathlib import Path
from typing import Any, Collection, Dict

import mutf8
import pandas as pd
from IPython.display import Markdown, display
from nbt import nbt, region

# %%
save_folder = Path(environ["SAVE_PATH"])

# %%
def get_name(entity: Dict[str, Any]) -> str:
    """Return the name (or identifier) of an entity

    Parameters
    ----------
    entity: dict
        The entity of interest

    Returns
    -------
    str
        The name and ID (or just the ID) of the entity
    """
    identifier = entity["id"]

    if "CustomName" not in entity.keys():
        return str(identifier)
    custom_name = json.loads(entity["CustomName"].value)
    try:
        name = custom_name["text"]  # 1.20.1-
    except TypeError:
        name = custom_name  # 1.20.3+
    return f"{name} ({identifier})"

# %%
def find_horseys(path: Path) -> list[Dict[str, Any]]:
    """Find and return all hawses
    in a given entities file

    Parameters
    ----------
    path : Path
        The path to the entities file

    Returns
    -------
    list of dict
        The attributes of all found horse
    """
    horses = []
    for chunk in region.RegionFile(path).iter_chunks():
        for entity in chunk["Entities"]:
            if entity["id"].value not in (
                "minecraft:horse",
                "minecraft:mule",
                "minecraft:donkey",
            ):
                continue
            attributes: Dict[str, Any] = {"name": get_name(entity)}
            attributes["wild"] = "Owner" not in entity
            attributes["location"] = tuple(
                int(v.value) for i, v in enumerate(entity["Pos"]) if i != 1
            )

            for attr in entity["Attributes"]:
                if any(
                    keyword in attr["Name"].value
                    for keyword in ("armor", "knockback", "follow_range")
                ):
                    continue
                attributes[attr["Name"].value.split(":")[-1].split(".")[-1]] = attr[
                    "Base"
                ].value

            horses.append(attributes)
    return horses

# %%
# %%time
horse_data = []
futures = []
with ProcessPoolExecutor(max_workers=7) as executor:
    for path in sorted((save_folder / "entities").glob("*")):
        futures.append(executor.submit(find_horseys, path))

for result in as_completed(futures):
    horse_data.extend(result.result())

horse_dataframe = (
    pd.DataFrame(horse_data)
    .sort_values("movement_speed", ascending=False)
    .reset_index(drop=True)
)
horse_dataframe
# Out:
# CPU times: user 62.3 ms, sys: 52.7 ms, total: 115 ms
# Wall time: 967 ms
#                                          name   wild        location  \
# 0             Coltneighsegg (minecraft:horse)  False  (-1487, -3954)
# 1    Juan Maneuel Fangiwhoa (minecraft:horse)  False  (-1519, -3957)
# 2         Bugatti Neigh-ron (minecraft:horse)  False  (-1514, -3956)
# 3           Paganeigh Hayra (minecraft:horse)  False  (-1523, -3973)
# 4       Alfalfa Roam-mare-o (minecraft:horse)  False  (-1493, -3943)
# ..                                        ...    ...             ...
# 166                          minecraft:donkey   True   (-334, -1238)
# 167                          minecraft:donkey   True   (-329, -1224)
# 168                          minecraft:donkey   True   (-328, -1221)
# 169                          minecraft:donkey   True   (-653, -4377)
# 170                          minecraft:donkey   True   (-461, -5498)
#
#      max_health  movement_speed  jump_strength
# 0     24.000000        0.321808       0.863070
# 1     20.000000        0.316517       0.791625
# 2     19.000000        0.313177       0.881441
# 3     24.464658        0.311544       0.768651
# 4     19.000000        0.308744       0.839726
# ..          ...             ...            ...
# 166   22.000000             NaN            NaN
# 167   24.000000             NaN            NaN
# 168   19.000000             NaN            NaN
# 169   23.000000             NaN            NaN
# 170   21.000000             NaN            NaN
#
# [171 rows x 6 columns]

# %% [markdown]
# Since the last time I uploaded this script, I've done a bunch of husbandry,
# so it's pretty gratifying to see that I've got **all five** of the five fastest horses. It's also cool to note that there's still room for improvement, as [max movement speed is 0.3375](https://minecraft.wiki/w/Horse#Movement_speed), and my fastest super~~car~~horse is only at 0.322.
#
# Slicing out the wild ones, we have:

# %%
horse_dataframe.loc[~horse_dataframe.wild]
# Out:
#                                          name   wild        location  \
# 0             Coltneighsegg (minecraft:horse)  False  (-1487, -3954)
# 1    Juan Maneuel Fangiwhoa (minecraft:horse)  False  (-1519, -3957)
# 2         Bugatti Neigh-ron (minecraft:horse)  False  (-1514, -3956)
# 3           Paganeigh Hayra (minecraft:horse)  False  (-1523, -3973)
# 4       Alfalfa Roam-mare-o (minecraft:horse)  False  (-1493, -3943)
# 7          Mareclaren 570LT (minecraft:horse)  False  (-1509, -3953)
# 10      Ponticlack Firebird (minecraft:horse)  False  (-1502, -3946)
# 12            Lacia Foalvia (minecraft:horse)  False  (-1524, -3945)
# 14            Marecedes SLS (minecraft:horse)  False  (-1493, -3952)
# 16          Lamborghi-neigh (minecraft:horse)  False  (-1487, -3970)
# 17                            minecraft:horse  False   (-936, -5322)
# 19            Mareclaren P1 (minecraft:horse)  False  (-1493, -3946)
# 43                            minecraft:horse  False  (-6163, -6286)
# 50                            minecraft:horse  False  (-1503, -3978)
# 57              Horsche 924 (minecraft:horse)  False  (-1495, -3952)
# 63               Whinnie R8 (minecraft:horse)  False  (-1511, -3945)
# 66                            minecraft:horse  False   (-983, -4277)
# 67                Ca-Mare-o (minecraft:horse)  False  (-1500, -3958)
# 68             Samuel Camino (minecraft:mule)  False  (-1521, -3972)
# 84                    Muleoo (minecraft:mule)  False  (-1495, -3945)
# 86                            minecraft:horse  False  (-1010, -5143)
# 87                            minecraft:horse  False   (-907, -5283)
# 94            ...Mustang... (minecraft:horse)  False  (-1513, -3973)
# 95                            minecraft:horse  False  (-3003, -3629)
# 117            Ferrar-neigh (minecraft:horse)  False  (-1494, -3959)
# 122                          minecraft:donkey  False  (-1523, -3990)
# 123                  F-150 (minecraft:donkey)  False  (-1525, -3947)
# 124                  Hilux (minecraft:donkey)  False  (-1492, -3950)
# 127                          minecraft:donkey  False  (-1487, -3959)
# 128        Nissan Frontier (minecraft:donkey)  False  (-1494, -3962)
# 130                          minecraft:donkey  False   (4273, -4925)
# 131                          minecraft:donkey  False   (1114, -2825)
# 163              Dodge Colt (minecraft:horse)  False  (-1514, -3972)
#
#      max_health  movement_speed  jump_strength
# 0     24.000000        0.321808       0.863070
# 1     20.000000        0.316517       0.791625
# 2     19.000000        0.313177       0.881441
# 3     24.464658        0.311544       0.768651
# 4     19.000000        0.308744       0.839726
# 7     23.000000        0.299387       0.756016
# 10    20.000000        0.287003       0.494529
# 12    22.333333        0.276493       0.808521
# 14    23.000000        0.273471       0.825461
# 16    27.000000        0.271633       0.566055
# 17    21.000000        0.271523       0.663700
# 19    23.000000        0.270267       0.864608
# 43    27.000000        0.249392       0.665574
# 50    22.000000        0.244324       0.696182
# 57    19.000000        0.238490       0.840111
# 63    23.000000        0.233374       0.689507
# 66    21.000000        0.232124       0.910533
# 67    21.000000        0.232040       0.852316
# 68    28.333333        0.231659       0.628128
# 84    24.333333        0.213634       0.550304
# 86    25.000000        0.212723       0.855987
# 87    26.000000        0.210641       0.713664
# 94    19.000000        0.204353       0.783790
# 95    26.000000        0.203943       0.560632
# 117   29.000000        0.182948       0.746220
# 122   21.000000        0.175000            NaN
# 123   25.000000        0.175000            NaN
# 124   27.000000        0.175000            NaN
# 127   25.000000        0.175000            NaN
# 128   15.000000        0.175000            NaN
# 130   27.000000        0.175000            NaN
# 131   22.000000        0.175000            NaN
# 163   18.000000        0.138639       0.685687

# %% [markdown]
# It also might be worth trying my hand at mule-breeding again, since Samuel Camino is slower than the midpoint of Coltneighness crossed with a base donkey.
#
# Moving onto jump strength:

# %%
horse_dataframe.sort_values("jump_strength", ascending=False).reset_index(drop=True)
# Out:
#                  name   wild        location  max_health  movement_speed  \
# 0     minecraft:horse   True  (-1229, -5374)        29.0        0.236095
# 1     minecraft:horse  False   (-983, -4277)        21.0        0.232124
# 2     minecraft:horse   True   (-462, -5377)        18.0        0.214107
# 3     minecraft:horse   True  (-7022, -1925)        24.0        0.250328
# 4     minecraft:horse   True   (-788, -5326)        24.0        0.225324
# ..                ...    ...             ...         ...             ...
# 166  minecraft:donkey   True   (-334, -1238)        22.0             NaN
# 167  minecraft:donkey   True   (-329, -1224)        24.0             NaN
# 168  minecraft:donkey   True   (-328, -1221)        19.0             NaN
# 169  minecraft:donkey   True   (-653, -4377)        23.0             NaN
# 170  minecraft:donkey   True   (-461, -5498)        21.0             NaN
#
#      jump_strength
# 0         0.924284
# 1         0.910533
# 2         0.909173
# 3         0.891672
# 4         0.888814
# ..             ...
# 166            NaN
# 167            NaN
# 168            NaN
# 169            NaN
# 170            NaN
#
# [171 rows x 6 columns]

# %%
_.loc[~_.wild]  # type: ignore
# Out:
#                                          name   wild        location  \
# 1                             minecraft:horse  False   (-983, -4277)
# 5         Bugatti Neigh-ron (minecraft:horse)  False  (-1514, -3956)
# 9             Mareclaren P1 (minecraft:horse)  False  (-1493, -3946)
# 10            Coltneighsegg (minecraft:horse)  False  (-1487, -3954)
# 13                            minecraft:horse  False  (-1010, -5143)
# 14                Ca-Mare-o (minecraft:horse)  False  (-1500, -3958)
# 19              Horsche 924 (minecraft:horse)  False  (-1495, -3952)
# 20      Alfalfa Roam-mare-o (minecraft:horse)  False  (-1493, -3943)
# 23            Marecedes SLS (minecraft:horse)  False  (-1493, -3952)
# 27            Lacia Foalvia (minecraft:horse)  False  (-1524, -3945)
# 30   Juan Maneuel Fangiwhoa (minecraft:horse)  False  (-1519, -3957)
# 32            ...Mustang... (minecraft:horse)  False  (-1513, -3973)
# 41          Paganeigh Hayra (minecraft:horse)  False  (-1523, -3973)
# 46         Mareclaren 570LT (minecraft:horse)  False  (-1509, -3953)
# 50             Ferrar-neigh (minecraft:horse)  False  (-1494, -3959)
# 61                            minecraft:horse  False   (-907, -5283)
# 71                            minecraft:horse  False  (-1503, -3978)
# 73               Whinnie R8 (minecraft:horse)  False  (-1511, -3945)
# 76               Dodge Colt (minecraft:horse)  False  (-1514, -3972)
# 91                            minecraft:horse  False  (-6163, -6286)
# 93                            minecraft:horse  False   (-936, -5322)
# 107            Samuel Camino (minecraft:mule)  False  (-1521, -3972)
# 126         Lamborghi-neigh (minecraft:horse)  False  (-1487, -3970)
# 127                           minecraft:horse  False  (-3003, -3629)
# 131                   Muleoo (minecraft:mule)  False  (-1495, -3945)
# 138     Ponticlack Firebird (minecraft:horse)  False  (-1502, -3946)
# 139                          minecraft:donkey  False  (-1523, -3990)
# 140                  F-150 (minecraft:donkey)  False  (-1525, -3947)
# 141                  Hilux (minecraft:donkey)  False  (-1492, -3950)
# 144                          minecraft:donkey  False  (-1487, -3959)
# 145        Nissan Frontier (minecraft:donkey)  False  (-1494, -3962)
# 147                          minecraft:donkey  False   (4273, -4925)
# 148                          minecraft:donkey  False   (1114, -2825)
#
#      max_health  movement_speed  jump_strength
# 1     21.000000        0.232124       0.910533
# 5     19.000000        0.313177       0.881441
# 9     23.000000        0.270267       0.864608
# 10    24.000000        0.321808       0.863070
# 13    25.000000        0.212723       0.855987
# 14    21.000000        0.232040       0.852316
# 19    19.000000        0.238490       0.840111
# 20    19.000000        0.308744       0.839726
# 23    23.000000        0.273471       0.825461
# 27    22.333333        0.276493       0.808521
# 30    20.000000        0.316517       0.791625
# 32    19.000000        0.204353       0.783790
# 41    24.464658        0.311544       0.768651
# 46    23.000000        0.299387       0.756016
# 50    29.000000        0.182948       0.746220
# 61    26.000000        0.210641       0.713664
# 71    22.000000        0.244324       0.696182
# 73    23.000000        0.233374       0.689507
# 76    18.000000        0.138639       0.685687
# 91    27.000000        0.249392       0.665574
# 93    21.000000        0.271523       0.663700
# 107   28.333333        0.231659       0.628128
# 126   27.000000        0.271633       0.566055
# 127   26.000000        0.203943       0.560632
# 131   24.333333        0.213634       0.550304
# 138   20.000000        0.287003       0.494529
# 139   21.000000        0.175000            NaN
# 140   25.000000        0.175000            NaN
# 141   27.000000        0.175000            NaN
# 144   25.000000        0.175000            NaN
# 145   15.000000        0.175000            NaN
# 147   27.000000        0.175000            NaN
# 148   22.000000        0.175000            NaN

# %% [markdown]
# This isn't really something I'm looking at investing in right now, but it's cool to see that two of my fastest horses are also among my best jumpers.
